# %%
import pandas as pd

# %%
path = "Desktop/data/housing data/housingdata.csv"
df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-c9de6257ff9f> in <module>
#       1 path = "Desktop/data/housing data/housingdata.csv"
# ----> 2 df = pd.read_csv(path)
#
# ...

# %% [markdown]
#  ### Variables in order:
#  1. CRIM     per capita crime rate by town
#  2. ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#  3. INDUS    proportion of non-retail business acres per town
#  4. CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#  5. NOX      nitric oxides concentration (parts per 10 million)
#  6. RM       average number of rooms per dwelling
#  7. AGE      proportion of owner-occupied units built prior to 1940
#  8. DIS      weighted distances to five Boston employment centres
#  9. RAD      index of accessibility to radial highways
#  10. TAX      full-value property-tax rate per 10,000 dollars
#  11. PTRATIO  pupil-teacher ratio by town
#  12. B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#  13. LSTAT    % lower status of the population
#  14. MEDV     Median value of owner-occupied homes in 1000 USD

# %%
df.columns = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']

# %%
df.head()
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 1  0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 2  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 3  0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 4  0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   9.14  21.6
# 1  392.83   4.03  34.7
# 2  394.63   2.94  33.4
# 3  396.90   5.33  36.2
# 4  394.12   5.21  28.7

# %%
corr = df.corr()
corr
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200283  0.406251 -0.056132  0.420934 -0.218978  0.352701
# ZN      -0.200283  1.000000 -0.534022 -0.042550 -0.516574  0.311835 -0.569524
# INDUS    0.406251 -0.534022  1.000000  0.062350  0.764556 -0.391330  0.645543
# CHAS    -0.056132 -0.042550  0.062350  1.000000  0.091134  0.091497  0.086461
# NOX      0.420934 -0.516574  0.764556  0.091134  1.000000 -0.302127  0.731461
# RM      -0.218978  0.311835 -0.391330  0.091497 -0.302127  1.000000 -0.240211
# AGE      0.352701 -0.569524  0.645543  0.086461  0.731461 -0.240211  1.000000
# DIS     -0.379627  0.664395 -0.708848 -0.099109 -0.769221  0.205170 -0.747872
# RAD      0.625396 -0.311717  0.594167 -0.007907  0.611758 -0.209277  0.456232
# TAX      0.582568 -0.314351  0.720561 -0.035965  0.668141 -0.291680  0.506527
# PTRATIO  0.289394 -0.391713  0.380955 -0.122570  0.188918 -0.355116  0.261724
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
mask = np.triu(np.ones_like(corr,dtype=bool))

f,ax = plt.subplots(figsize=(12,10))

sns.heatmap(corr,mask=mask,cmap= 'RdBu')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size=0.66)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train.iloc[:,:] = scaler.fit_transform(X_train.iloc[:,:])
X_test.iloc[:,:] = scaler.transform(X_test.iloc[:,:])
# Out:
# c:\users\anike\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1737: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# c:\users\anike\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1737: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
X_train.to_csv('Desktop/data/housingdata_train.csv', header=True,index = False)
X_test.to_csv('Desktop/data/housingdata_test.csv', header=True,index = False)

# %%
df.to_csv('Desktop/data/housingdata.csv', header=True,index = False)

# %%
df['ZN'].value_counts()
# Out:
# 0.0      372
# 20.0      21
# 80.0      15
# 12.5      10
# 25.0      10
# 22.0      10
# 40.0       7
# 30.0       6
# 45.0       6
# 90.0       5
# 21.0       4
# 60.0       4
# 95.0       4
# 33.0       4
# 28.0       3
# 52.5       3
# 75.0       3
# 34.0       3
# 35.0       3
# 55.0       3
# 70.0       3
# 82.5       2
# 85.0       2
# 100.0      1
# 17.5       1
# Name: ZN, dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean     3.620667   11.350495   11.154257    0.069307    0.554728    6.284059
# std      8.608572   23.343704    6.855868    0.254227    0.115990    0.703195
# min      0.009060    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082210    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.259150    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.678220   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    68.581584    3.794459    9.566337  408.459406   18.461782  356.594376
# ...

# %%
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1868f20d1f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1868f20d8b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1868f1fee50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1868f20df70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1868f218310>],
#  'means': []}

# %%
plt.hist(df['AGE'])
# Out:
# (array([ 14.,  31.,  29.,  42.,  32.,  38.,  38.,  42.,  71., 168.]),
#  array([  2.9 ,  12.61,  22.32,  32.03,  41.74,  51.45,  61.16,  70.87,
#          80.58,  90.29, 100.  ]),
#  <BarContainer object of 10 artists>)

# %%
df[df['AGE']]
